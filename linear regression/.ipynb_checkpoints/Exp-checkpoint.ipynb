# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
boston=load_boston()

# %%
feature = pd.DataFrame(boston.data,columns=boston.feature_names)
target = pd.DataFrame(boston.target, columns=["Target"])

# %%
data= pd.concat([feature,target],axis=1)

# %%
correlation=data.corr("pearson")

# %%
abs(correlation["Target"]).sort_values()
# Out:
# CHAS       0.175260
# DIS        0.249929
# B          0.333461
# ZN         0.360445
# AGE        0.376955
# RAD        0.381626
# CRIM       0.388305
# NOX        0.427321
# TAX        0.468536
# INDUS      0.483725
# PTRATIO    0.507787
# RM         0.695360
# LSTAT      0.737663
# Target     1.000000
# Name: Target, dtype: float64

# %%
X=data["RM"]
Y=data["Target"]
Z=data["LSTAT"]

# %%
plt.plot(Z,Y,'.')

# %%
X=(X-X.min())/(X.max()-X.min())
Y=(Y-Y.min())/(Y.max()-Y.min())
Z=(Z-Z.min())/(Z.max()-Z.min())

# %%
plt.plot(X,Y,'r.', Z,Y,'b.')
# Out:
# [<matplotlib.lines.Line2D at 0x25d4efc1470>,
#  <matplotlib.lines.Line2D at 0x25d4efc15c0>]

# %%
x=np.array(X)
y=np.array(Y)
z=np.array(Z)

# %%
x_train,x_test,y_train,y_test=train_test_split(z,y,test_size=0.2)

# %%
np.power(np.e,2)
# Out:
# 7.3890560989306495

# %%
def hypothesis(a,x,b):
    return np.power(np.e,-(a*x+b))

# %%
def error(a,x,b,y):
    e=0
    m=len(x)
    
    for i in range(m):
        e += np.power((hypothesis(a,x[i],b)-y[i]),2)
        
    return (1/(2*m))*e

# %%
def step_gradient(a,x,b,y,learning_rate):
    grad_a=0
    grad_b=0
    m=len(x)
    
    for i in range(m):
        grad_a += (1/m)*(hypothesis(a,x[i],b)-y[i])*(hypothesis(a,x[i],b)*x[i])*-1
        grad_b += (1/m)*(hypothesis(a,x[i],b)-y[i])*(hypothesis(a,x[i],b))*-1
        
    a=a-grad_a*learning_rate
    b=b-grad_b*learning_rate
        
    return a,b

# %%
def descent(init_a,x,init_b,y,learning_rate,iterations):
    a=init_a
    b=init_b
    
    for i in range(iterations):
        e = error(a,x,b,y)
        
        if i%1000==0:
            print(f"Error:{np.sqrt(e)},a:{a},b:{b}")
                  
        a,b = step_gradient(a,x,b,y,learning_rate)
                  
    return a,b

# %%
a=0.33882130305029956
b=0.7636677237991352
learning_rate=0.001
iterations=10000

# %%
final_a,final_b = descent(a,x_train,b,y_train,learning_rate,iterations)
# Out:
# Error:0.12894180537375063,a:0.33882130305029956,b:0.7636677237991352
# Error:0.1279164197937518,a:0.3511735464306417,b:0.7741619689065388
# Error:0.12714143444221998,a:0.3626569768124513,b:0.7822478879835421
# Error:0.1265309036564868,a:0.3734455301547057,b:0.7884300171846428
# Error:0.1260302837920449,a:0.38367084579228056,b:0.7930893649870386
# Error:0.12560425194236638,a:0.3934344419319845,b:0.7965192460198992
# Error:0.12522954369766107,a:0.40281582370396196,b:0.7989490631735245
# Error:0.12489061916189576,a:0.41187805422155177,b:0.8005605948139831
# Error:0.12457697486786758,a:0.42067168683560774,b:0.8014994550059357
# Error:0.12428144071923859,a:0.42923760620041906,b:0.8018833493741135

# %%
plt.plot(x_train,y_train, 'r.',
        x_train, hypothesis(a,x_train,b),'b',
        x_train, hypothesis(final_a,x_train,final_b),'g')
# Out:
# [<matplotlib.lines.Line2D at 0x25d4f1b4fd0>,
#  <matplotlib.lines.Line2D at 0x25d4f1be128>,
#  <matplotlib.lines.Line2D at 0x25d4f1be4e0>]

# %%
plt.plot(x_test,y_test, 'r.',
        x_test, hypothesis(a,x_test,b),'b',
        x_test, hypothesis(final_a,x_test,final_b),'g')
# Out:
# [<matplotlib.lines.Line2D at 0x25d4f2194e0>,
#  <matplotlib.lines.Line2D at 0x25d4f2195f8>,
#  <matplotlib.lines.Line2D at 0x25d4f2199b0>]

# %%
final_a,final_b
# Out:
# (0.43760912322642903, 0.8018081465348896)

# %%
y_test[:3]
# Out:
# array([0.62666667, 0.39555556, 0.18888889])

# %%
hypothesis(final_a,x_test[:3],final_b)
# Out:
# array([0.42571998, 0.40369129, 0.37326242])

# %%
np.sqrt(error(final_a,x_train,final_b,y_train))
# Out:
# 0.12399908104696655

# %%
np.sqrt(error(final_a,x_test,final_b,y_test))
# Out:
# 0.14224070121322818
